# %% [markdown]
# # Single Cell Sequencing
# ## Creates h5ad files
#
#
# Uses exon data extracted from: zUMIs_output\expression\*.dgecounts.rds and gene data from: zUMIs_output\expression\*.gene_names.txt<br>
# Creates h5ad file from anndata objects. Each file represents data from one plate (sample)<br>

# %%
# !pip install --quiet anndata
import numpy as np
import pandas as pd
import anndata as ad
# !pip install pyreadr
import pyreadr
import config as general_paths
import os
import warnings
warnings.filterwarnings("ignore")

# %%
figure_path = general_paths.figures_path
data_path = general_paths.data_path
output_path = general_paths.output_path
local_path = general_paths.local_path
rds_file_sample1 = os.path.join(local_path, "alignment/sample1.rds") # the file read and prepared in R
h5ad_file_sample1 = os.path.join(local_path, "alignment/sample1.h5ad")  # the file that will be used for Melisas script

# %%
rds_file_sample1 = os.path.join(local_path, "alignment/sample1.rds") # the file read and prepared in R
h5ad_file_sample1 = os.path.join(local_path, "alignment/sample1.h5ad")  # the file that will be used for Melisas script

rds_file_sample2 = os.path.join(local_path, "alignment/sample2.rds") # the file read and prepared in R
h5ad_file_sample2 = os.path.join(local_path, "alignment/sample2.h5ad")  # the file that will be used for Melisas script

rds_file_sample3 = os.path.join(local_path, "alignment/sample3.rds") # the file read and prepared in R
h5ad_file_sample3 = os.path.join(local_path, "alignment/sample3.h5ad")  # the file that will be used for Melisas script

rds_file_sample4 = os.path.join(local_path, "alignment/sample4.rds") # the file read and prepared in R
h5ad_file_sample4 = os.path.join(local_path, "alignment/sample4.h5ad")  # the file that will be used for Melisas script

rds_file_sample5 = os.path.join(local_path, "alignment/sample5.rds") # the file read and prepared in R
h5ad_file_sample5 = os.path.join(local_path, "alignment/sample5.h5ad")  # the file that will be used for Melisas script

rds_file_sample6 = os.path.join(local_path, "alignment/sample6.rds") # the file read and prepared in R
h5ad_file_sample6 = os.path.join(local_path, "alignment/sample6.h5ad")  # the file that will be used for Melisas script

rds_file_sample7 = os.path.join(local_path, "alignment/sample7.rds") # the file read and prepared in R
h5ad_file_sample7 = os.path.join(local_path, "alignment/sample7.h5ad")  # the file that will be used for Melisas script

rds_file_sample8 = os.path.join(local_path, "alignment/sample8.rds") # the file read and prepared in R
h5ad_file_sample8 = os.path.join(local_path, "alignment/sample8.h5ad")  # the file that will be used for Melisas script

rds_file_sample9 = os.path.join(local_path, "alignment/sample9.rds") # the file read and prepared in R
h5ad_file_sample9 = os.path.join(local_path, "alignment/sample9.h5ad")  # the file that will be used for Melisas script

rds_file_sample10 = os.path.join(local_path, "alignment/sample10.rds") # the file read and prepared in R
h5ad_file_sample10 = os.path.join(local_path, "alignment/sample10.h5ad")  # the file that will be used for Melisas script

rds_file_sample11 = os.path.join(local_path, "alignment/sample11.rds") # the file read and prepared in R
h5ad_file_sample11 = os.path.join(local_path, "alignment/sample11.h5ad")  # the file that will be used for Melisas script

# file with gene ids and names from kallisto
t2g_file_path = os.path.join(local_path, "t2g.txt")

# %%
# Read the RDS file and convert to a DataFrame
rds_sample1 = pyreadr.read_r(rds_file_sample1)
rds_sample2 = pyreadr.read_r(rds_file_sample2)
rds_sample3 = pyreadr.read_r(rds_file_sample3)
rds_sample4 = pyreadr.read_r(rds_file_sample4)
rds_sample5 = pyreadr.read_r(rds_file_sample5)
rds_sample6 = pyreadr.read_r(rds_file_sample6)
rds_sample7 = pyreadr.read_r(rds_file_sample7)
rds_sample8 = pyreadr.read_r(rds_file_sample8)
rds_sample9 = pyreadr.read_r(rds_file_sample9)
rds_sample10 = pyreadr.read_r(rds_file_sample10)
rds_sample11 = pyreadr.read_r(rds_file_sample11)

# %%
# convert to dataframes (they are different sizes)
rds_sample1_df = rds_sample1[list(rds_sample1.keys())[0]]
rds_sample2_df = rds_sample2[list(rds_sample2.keys())[0]]
rds_sample3_df = rds_sample3[list(rds_sample3.keys())[0]]
rds_sample4_df = rds_sample4[list(rds_sample4.keys())[0]]
rds_sample5_df = rds_sample5[list(rds_sample5.keys())[0]]
rds_sample6_df = rds_sample6[list(rds_sample6.keys())[0]]
rds_sample7_df = rds_sample7[list(rds_sample7.keys())[0]]
rds_sample8_df = rds_sample8[list(rds_sample8.keys())[0]]
rds_sample9_df = rds_sample9[list(rds_sample9.keys())[0]]
rds_sample10_df = rds_sample10[list(rds_sample10.keys())[0]]
rds_sample11_df = rds_sample11[list(rds_sample11.keys())[0]]
print(rds_sample11_df.shape)
# Out:
# (28914, 384)

# %%
# merge whole dataframe, so that all will have the same amount of genes
unified_df = pd.concat([rds_sample1_df,rds_sample2_df,rds_sample3_df,rds_sample4_df,rds_sample5_df,rds_sample6_df,rds_sample7_df,rds_sample8_df,rds_sample9_df,rds_sample10_df,rds_sample11_df],axis=1)
# replace all NaN values with zero counts
unified_df = unified_df.fillna(0.0)
unified_df
# Out:
#                AACCATCGGCAACTACCACT  AACCATCGGCAAGTTATCGG  \
# rownames
# 0610005C13Rik                   0.0                   0.0
# 0610009E02Rik                   0.0                   0.0
# 0610009L18Rik                   3.0                   0.0
# 0610010K14Rik                   2.0                   2.0
# 0610025J13Rik                   0.0                   0.0
# ...                             ...                   ...
# Trav6-7-dv9                     0.0                   0.0
# Usp9y                           0.0                   0.0
# Vmn1r80                         0.0                   0.0
# Wfdc11                          0.0                   0.0
# Zfp36l3                         0.0                   0.0
#
#                AACCATCGGCCACAATCCAC  AACCATCGGCCACTAACCGG  \
# rownames
# 0610005C13Rik                   0.0                   0.0
# 0610009E02Rik                   0.0                   0.0
# 0610009L18Rik                   2.0                   0.0
# ...

# %%
# t2g = pd.read_csv(t2g_file_path, header=None, names=["tid", "gene_id", "gene_name"], sep="\t")
# t2g.index = t2g.gene_id### FOR THAT WE USE T2G VARIABLE THAT OPENS T2G FILE (FILE WITH LINK BETWEEN GENE CODE AND GENE NAME)

# t2g = t2g.loc[~t2g.index.duplicated(keep='first')]
# gene_ids_kallisto = t2g['gene_id'].tolist()
# gene_ids_scilifelab = list(unified_df.index)
# diffelence1 = list(set(gene_ids_kallisto) - set(gene_ids_scilifelab))
# diffelence2 = list(set(gene_ids_scilifelab) - set(gene_ids_kallisto))
# print(f"Gene ids that are in kallisto file but not in scilifelab: {len(diffelence1)}\nGene ids that are in scilifelab but not in kallisto: {len(diffelence2)}") 
# # there are 308 gene ids from scilifelab that are not in kallisto ids!

# %%
# split back to original dataframes but same numbers of genes now
# check how many cells were in each of the data sets
total_barcodes_df1 = rds_sample1_df.shape[1]
total_barcodes_df2 = rds_sample2_df.shape[1]
total_barcodes_df3 = rds_sample3_df.shape[1]
total_barcodes_df4 = rds_sample4_df.shape[1]
total_barcodes_df5 = rds_sample5_df.shape[1]
total_barcodes_df6 = rds_sample6_df.shape[1]
total_barcodes_df7 = rds_sample7_df.shape[1]
total_barcodes_df8 = rds_sample8_df.shape[1]
total_barcodes_df9 = rds_sample9_df.shape[1]
total_barcodes_df10 = rds_sample10_df.shape[1]
total_barcodes_df11 = rds_sample11_df.shape[1]

# %%
rds_sample1_df = unified_df.iloc[:,0:total_barcodes_df1]
till_col = total_barcodes_df1+total_barcodes_df2
rds_sample2_df = unified_df.iloc[:,total_barcodes_df1:till_col]
from_col = till_col
till_col = from_col+total_barcodes_df3
rds_sample3_df = unified_df.iloc[:,from_col:till_col]
from_col = till_col
till_col = from_col+total_barcodes_df4
rds_sample4_df = unified_df.iloc[:,from_col:till_col]
from_col = till_col
till_col = from_col+total_barcodes_df5
rds_sample5_df = unified_df.iloc[:,from_col:till_col]
from_col = till_col
till_col = from_col+total_barcodes_df6
rds_sample6_df = unified_df.iloc[:,from_col:till_col]
from_col = till_col
till_col = from_col+total_barcodes_df7
rds_sample7_df = unified_df.iloc[:,from_col:till_col]
from_col = till_col
till_col = from_col+total_barcodes_df8
rds_sample8_df = unified_df.iloc[:,from_col:till_col]
from_col = till_col
till_col = from_col+total_barcodes_df9
rds_sample9_df = unified_df.iloc[:,from_col:till_col]
from_col = till_col
till_col = from_col+total_barcodes_df10
rds_sample10_df = unified_df.iloc[:,from_col:till_col]
from_col = till_col
till_col = from_col+total_barcodes_df11
rds_sample11_df = unified_df.iloc[:,from_col:till_col]

# verify number of cells in each new dataframe
rds_sample1_df.shape[1],rds_sample2_df.shape[1],rds_sample3_df.shape[1],rds_sample4_df.shape[1],rds_sample5_df.shape[1],rds_sample6_df.shape[1],rds_sample7_df.shape[1],rds_sample8_df.shape[1],rds_sample9_df.shape[1],rds_sample10_df.shape[1],rds_sample11_df.shape[1]
# Out:
# (384, 384, 384, 384, 384, 384, 384, 384, 384, 384, 384)

# %%
# transpose before creating anndata object, so that gene ids are columns and barcodes are rows
transposed_rds_sample1_df = rds_sample1_df.transpose()# Create an AnnData object
adata1 = ad.AnnData(
    X=transposed_rds_sample1_df.values,  # Your data as numpy array
    obs={'barcode': transposed_rds_sample1_df.index},
    var={'gene_id': transposed_rds_sample1_df.columns}  
)
transposed_rds_sample2_df = rds_sample2_df.transpose()# Create an AnnData object
adata2 = ad.AnnData(
    X=transposed_rds_sample2_df.values,  # Your data as numpy array
    obs={'barcode': transposed_rds_sample2_df.index},
    var={'gene_id': transposed_rds_sample2_df.columns}  
)

transposed_rds_sample3_df = rds_sample3_df.transpose()# Create an AnnData object
adata3 = ad.AnnData(
    X=transposed_rds_sample3_df.values,  # Your data as numpy array
    obs={'barcode': transposed_rds_sample3_df.index},
    var={'gene_id': transposed_rds_sample3_df.columns}  
)

transposed_rds_sample4_df = rds_sample4_df.transpose()# Create an AnnData object
adata4 = ad.AnnData(
    X=transposed_rds_sample4_df.values,  # Your data as numpy array
    obs={'barcode': transposed_rds_sample4_df.index},
    var={'gene_id': transposed_rds_sample4_df.columns}  
)
transposed_rds_sample5_df = rds_sample5_df.transpose()# Create an AnnData object
adata5 = ad.AnnData(
    X=transposed_rds_sample5_df.values,  # Your data as numpy array
    obs={'barcode': transposed_rds_sample5_df.index},
    var={'gene_id': transposed_rds_sample5_df.columns}  
)

transposed_rds_sample6_df = rds_sample6_df.transpose()# Create an AnnData object
adata6 = ad.AnnData(
    X=transposed_rds_sample6_df.values,  # Your data as numpy array
    obs={'barcode': transposed_rds_sample6_df.index},
    var={'gene_id': transposed_rds_sample6_df.columns}  
)

transposed_rds_sample7_df = rds_sample7_df.transpose()# Create an AnnData object
adata7 = ad.AnnData(
    X=transposed_rds_sample7_df.values,  # Your data as numpy array
    obs={'barcode': transposed_rds_sample7_df.index},
    var={'gene_id': transposed_rds_sample7_df.columns}  
)
transposed_rds_sample8_df = rds_sample8_df.transpose()# Create an AnnData object
adata8 = ad.AnnData(
    X=transposed_rds_sample8_df.values,  # Your data as numpy array
    obs={'barcode': transposed_rds_sample8_df.index},
    var={'gene_id': transposed_rds_sample8_df.columns}  
)
transposed_rds_sample9_df = rds_sample9_df.transpose()# Create an AnnData object
adata9 = ad.AnnData(
    X=transposed_rds_sample9_df.values,  # Your data as numpy array
    obs={'barcode': transposed_rds_sample9_df.index},
    var={'gene_id': transposed_rds_sample9_df.columns}  
)


transposed_rds_sample10_df = rds_sample10_df.transpose()# Create an AnnData object
adata10 = ad.AnnData(
    X=transposed_rds_sample10_df.values,  # Your data as numpy array
    obs={'barcode': transposed_rds_sample10_df.index},
    var={'gene_id': transposed_rds_sample10_df.columns}  
)
transposed_rds_sample11_df = rds_sample11_df.transpose()# Create an AnnData object
adata11 = ad.AnnData(
    X=transposed_rds_sample11_df.values,  # Your data as numpy array
    obs={'barcode': transposed_rds_sample11_df.index},
    var={'gene_id': transposed_rds_sample11_df.columns}  
)

# %%
transposed_rds_sample11_df.index
# Out:
# Index(['CAAGGACATCCCATCTCCGT', 'CAAGGACATCCCGGAGCTAA', 'CAAGGACATCCCGTGTTACT',
#        'CAAGGACATCCGACGCAGAA', 'CAAGGACATCCTATCTAGTG', 'CAAGGACATCCTCTTATTCG',
#        'CAAGGACATCGCACAGTATT', 'CAAGGACATCTACAACTAGC', 'CAAGGACATCTAGGTGGCGA',
#        'CAAGGACATCTAGTTAGGCT',
#        ...
#        'TTGTCTGCAAGCACAGTATT', 'TTGTCTGCAATACAACTAGC', 'TTGTCTGCAATAGGTGGCGA',
#        'TTGTCTGCAATAGTTAGGCT', 'TTGTCTGCAATCTGCAACAA', 'TTGTCTGCAATGCATCATAC',
#        'TTGTCTGCAATGGCCTTAAT', 'TTGTCTGCAATTACAACACG', 'TTGTCTGCAATTCAGGAGAT',
#        'TTGTCTGCAATTCTCTGATC'],
#       dtype='object', length=384)

# %%
# save h5ad files that are necessary for further Melisas pipeline
adata1.write(h5ad_file_sample1)
adata2.write(h5ad_file_sample2)
adata3.write(h5ad_file_sample3)
adata4.write(h5ad_file_sample4)
adata5.write(h5ad_file_sample5)
adata6.write(h5ad_file_sample6)
adata7.write(h5ad_file_sample7)
adata8.write(h5ad_file_sample8)
adata9.write(h5ad_file_sample9)
adata10.write(h5ad_file_sample10)
adata11.write(h5ad_file_sample11)

# %%
print(adata1.shape)
genes_list = ['TdTomato','Cre','Campari','rRNA_18s_1870bp','EGFP','mNeptune','ReachR','flp0','iCre'] 

for gene in adata1.var['gene_id']:
    for gene2 in genes_list : 
        if gene == gene2:
            print(gene)
# Out:
# (384, 35546)
# Campari
# Cre
# rRNA_18s_1870bp
# TdTomato
# EGFP
# iCre
# ReachR
# flp0

# %%
genes_names = []
for i in range(adata1.shape[1]):
    genes_names.append(adata1.var['gene_id'][i])
adata1.var["gene_name"] = genes_names
adata1.var.index = adata1.var["gene_name"]
# make names unique
adata1.var_names_make_unique()
'Cre' in adata1.var['gene_name'] # check if Piezo1 is still there
# Out:
# True

# %%
transposed_rds_sample1_df.shape
# Out:
# (384, 35546)
